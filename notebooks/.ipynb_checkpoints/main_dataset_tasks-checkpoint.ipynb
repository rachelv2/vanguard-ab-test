# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import polars as pl
import yaml

# %%
with open('../config.yaml', 'r') as file:
    config = yaml.safe_load(file)

# %%
# import the datasets
final_demo = pd.read_csv(config["input_data"]["file1"])
df_final_experiment_clients =pd.read_csv(config["input_data"]["file2"])
df_final_web_data_pt_1 = pd.read_csv(config["input_data"]["file3"])
df_final_web_data_pt_2 = pd.read_csv(config["input_data"]["file4"])

# %%
# check if there is an issue of column type
final_demo.dtypes, df_final_experiment_clients.dtypes, df_final_web_data_pt_1.dtypes
# Out:
# (client_id             int64
#  clnt_tenure_yr      float64
#  clnt_tenure_mnth    float64
#  clnt_age            float64
#  gendr                   str
#  num_accts           float64
#  bal                 float64
#  calls_6_mnth        float64
#  logons_6_mnth       float64
#  dtype: object,
#  client_id    int64
#  Variation      str
#  dtype: object,
#  client_id       int64
#  visitor_id        str
#  visit_id          str
#  process_step      str
#  date_time         str
#  dtype: object)

# %% [markdown]
# The dtype shows that the client_id is always an integer so theire is no issue for joining df

# %%
# remove rows from df_exeprimental_clients where variation is NA
df_final_experiment_clients = df_final_experiment_clients.dropna(subset=["Variation"])
df_final_experiment_clients.shape
# Out:
# (50500, 2)

# %% [markdown]
# The decrease of number of rows matches the limitation to clients that participated

# %% [markdown]
# ### Merge process

# %%
# combine the web data
concat_webdata = pd.concat([df_final_web_data_pt_1, df_final_web_data_pt_1], axis=0, join="outer")
concat_webdata.shape
# Out:
# (686282, 5)

# %%
# merge the demo
merged_demo = concat_webdata.merge(final_demo, on="client_id",how="left")
merged_demo.shape
# Out:
# (686282, 13)

# %% [markdown]
# The constant number of rows show the left join was made properly

# %%
# merge the experimental_clients
merged_experiment = merged_demo.merge(df_final_experiment_clients, on="client_id",how="left")
merged_experiment.shape
# Out:
# (686282, 14)

# %% [markdown]
# The constant number of rows show the left join was made properly

# %%
# separate process from final df
df = merged_experiment.copy()

# %% [markdown]
# ### Fixing steps

# %%
# fix : clean the duplicates values
df.drop_duplicates(inplace=True)

# %%
# fix: keep clients involved in the AB Testing
df = df.dropna(subset=["Variation"])

# %%
# fix: convert date str into a datetime
df['date_time'] = pd.to_datetime(df['date_time'])

# %% [markdown]
# Some client_ids were not matching. For example client_id = 6373617 was in df_final_web_data_pt_2 but not in expepriment either demo. This suggests a discrepancies between datasets (client_id in web data but not in demo for example)

# %% [markdown]
# Merge data process:
# First the 2 web-data files have been concatenated in order to get the biggest dataset of the process, with the prior variables to be investigated.
# Second, this dataset merged additional columns from final_demo which is the clients demographics.
# Third, the final exprimental client dataset was added in order to see if the client was involved in a test or control group.
# Then we assume to keep only data from our 2 samples.

# %% [markdown]
# ### Check timeframe and potential cuts

# %%
# check if the process wac cut the first and last days of the experience
first_d = df['date_time'].min()
last_d = df['date_time'].max()
first_d,last_d
# Out:
# (Timestamp('2017-03-15 00:19:28'), Timestamp('2017-04-30 23:58:00'))

# %% [markdown]
# The last date of web data is 30th of April. Therefore, it is within the exprimental timeframe (June)

# %%
first_day_sample = df[df['date_time'].dt.date == pd.to_datetime('2017-03-15').date()].sort_values(by=['date_time'], ascending=True).head(5)[['process_step', 'date_time']]
first_day_sample
# Out:
#       process_step           date_time
# 35293        start 2017-03-15 00:19:28
# 35292       step_1 2017-03-15 00:20:50
# 35291       step_2 2017-03-15 00:22:52
# 35290       step_3 2017-03-15 00:23:47
# 35289      confirm 2017-03-15 00:26:24

# %% [markdown]
# The first user completed the entire process therefore we consider there was no cut of the process due to the timeframe

# %%
# Filter df for a specific visit_id
visit_id_to_keep = "100952948_77681780860_858472"

df_filtered = df[df['visit_id'] == visit_id_to_keep].copy()

# Optional: sort by date_time for clarity
df_filtered = df_filtered.sort_values('date_time').reset_index(drop=True)

df_filtered
# Out:
# Empty DataFrame
# Columns: [client_id, visitor_id, visit_id, process_step, date_time, clnt_tenure_yr, clnt_tenure_mnth, clnt_age, gendr, num_accts, bal, calls_6_mnth, logons_6_mnth, Variation]
# Index: []

# %% [markdown]
# ### Keep first start datetime and last confirm datetime

# %%
# First start
first_start = (
    df[df['process_step'] == 'start']
    .groupby('visit_id', as_index=False)['date_time']
    .min()
    .rename(columns={'date_time': 'first_start_time'})
)

# Last confirm
last_confirm = (
    df[df['process_step'] == 'confirm']
    .groupby('visit_id', as_index=False)['date_time']
    .max()
    .rename(columns={'date_time': 'last_confirm_time'})
)

# Keep only visits that have both a start and a confirm
visit_limits = first_start.merge(last_confirm, on='visit_id', how='inner')

# Attach those limits back to the original data
df = df.merge(visit_limits, on='visit_id', how='inner')

# Keep only rows between first start and last confirm
df = df[
    (df['date_time'] >= df['first_start_time']) &
    (df['date_time'] <= df['last_confirm_time'])
].copy()

# Sort neatly
df = df.sort_values(['visit_id', 'date_time'])
df = df.reset_index(drop=True)

df.head(20)
# Out:
#     client_id             visitor_id                      visit_id  \
# 0     7338123  612065484_94198474375   100019538_17884295066_43909
# 1     7338123  612065484_94198474375   100019538_17884295066_43909
# 2     7338123  612065484_94198474375   100019538_17884295066_43909
# 3     7338123  612065484_94198474375   100019538_17884295066_43909
# 4     7338123  612065484_94198474375   100019538_17884295066_43909
# 5     7338123  612065484_94198474375   100019538_17884295066_43909
# 6     7338123  612065484_94198474375   100019538_17884295066_43909
# 7     7338123  612065484_94198474375   100019538_17884295066_43909
# 8     7338123  612065484_94198474375   100019538_17884295066_43909
# 9     7338123  612065484_94198474375   100019538_17884295066_43909
# 10    7338123  612065484_94198474375   100019538_17884295066_43909
# 11    3479519  194422203_56127484794   10006594_66157970412_679648
# 12    3479519  194422203_56127484794   10006594_66157970412_679648
# 13    3479519  194422203_56127484794   10006594_66157970412_679648
# 14    3479519  194422203_56127484794   10006594_66157970412_679648
# 15    3479519  194422203_56127484794   10006594_66157970412_679648
# 16    3479519  194422203_56127484794   10006594_66157970412_679648
# 17    3479519  194422203_56127484794   10006594_66157970412_679648
# 18    8631696  429350107_31978453627  100173292_91322748906_143563
# 19    8631696  429350107_31978453627  100173292_91322748906_143563
#
#    process_step           date_time  clnt_tenure_yr  clnt_tenure_mnth  \
# 0         start 2017-04-09 16:20:56             7.0              88.0
# 1        step_1 2017-04-09 16:21:12             7.0              88.0
# 2        step_2 2017-04-09 16:21:21             7.0              88.0
# 3        step_1 2017-04-09 16:21:35             7.0              88.0
# 4        step_1 2017-04-09 16:21:41             7.0              88.0
# 5         start 2017-04-09 16:21:45             7.0              88.0
# 6         start 2017-04-09 16:21:59             7.0              88.0
# 7        step_1 2017-04-09 16:22:04             7.0              88.0
# 8        step_2 2017-04-09 16:22:08             7.0              88.0
# 9        step_3 2017-04-09 16:24:01             7.0              88.0
# 10      confirm 2017-04-09 16:24:58             7.0              88.0
# 11        start 2017-04-13 11:50:18            12.0             150.0
# 12       step_1 2017-04-13 11:50:28            12.0             150.0
# 13       step_2 2017-04-13 11:50:38            12.0             150.0
# 14       step_3 2017-04-13 11:52:02            12.0             150.0
# 15       step_3 2017-04-13 11:56:11            12.0             150.0
# 16      confirm 2017-04-13 11:56:12            12.0             150.0
# 17       step_3 2017-04-13 11:56:12            12.0             150.0
# 18        start 2017-04-25 10:28:55            11.0             137.0
# 19       step_1 2017-04-25 10:29:06            11.0             137.0
#
#     clnt_age gendr  num_accts        bal  calls_6_mnth  logons_6_mnth  \
# 0       23.5     M        2.0   26436.73           6.0            9.0
# 1       23.5     M        2.0   26436.73           6.0            9.0
# 2       23.5     M        2.0   26436.73           6.0            9.0
# 3       23.5     M        2.0   26436.73           6.0            9.0
# 4       23.5     M        2.0   26436.73           6.0            9.0
# 5       23.5     M        2.0   26436.73           6.0            9.0
# 6       23.5     M        2.0   26436.73           6.0            9.0
# 7       23.5     M        2.0   26436.73           6.0            9.0
# 8       23.5     M        2.0   26436.73           6.0            9.0
# 9       23.5     M        2.0   26436.73           6.0            9.0
# 10      23.5     M        2.0   26436.73           6.0            9.0
# 11      52.5     F        2.0  349316.66           2.0            5.0
# 12      52.5     F        2.0  349316.66           2.0            5.0
# 13      52.5     F        2.0  349316.66           2.0            5.0
# 14      52.5     F        2.0  349316.66           2.0            5.0
# 15      52.5     F        2.0  349316.66           2.0            5.0
# 16      52.5     F        2.0  349316.66           2.0            5.0
# 17      52.5     F        2.0  349316.66           2.0            5.0
# 18      46.5     M        3.0  134716.64           3.0            6.0
# 19      46.5     M        3.0  134716.64           3.0            6.0
#
#    Variation    first_start_time   last_confirm_time
# 0       Test 2017-04-09 16:20:56 2017-04-09 16:24:58
# 1       Test 2017-04-09 16:20:56 2017-04-09 16:24:58
# 2       Test 2017-04-09 16:20:56 2017-04-09 16:24:58
# 3       Test 2017-04-09 16:20:56 2017-04-09 16:24:58
# 4       Test 2017-04-09 16:20:56 2017-04-09 16:24:58
# 5       Test 2017-04-09 16:20:56 2017-04-09 16:24:58
# 6       Test 2017-04-09 16:20:56 2017-04-09 16:24:58
# 7       Test 2017-04-09 16:20:56 2017-04-09 16:24:58
# 8       Test 2017-04-09 16:20:56 2017-04-09 16:24:58
# 9       Test 2017-04-09 16:20:56 2017-04-09 16:24:58
# 10      Test 2017-04-09 16:20:56 2017-04-09 16:24:58
# 11   Control 2017-04-13 11:50:18 2017-04-13 11:56:12
# 12   Control 2017-04-13 11:50:18 2017-04-13 11:56:12
# 13   Control 2017-04-13 11:50:18 2017-04-13 11:56:12
# 14   Control 2017-04-13 11:50:18 2017-04-13 11:56:12
# 15   Control 2017-04-13 11:50:18 2017-04-13 11:56:12
# 16   Control 2017-04-13 11:50:18 2017-04-13 11:56:12
# 17   Control 2017-04-13 11:50:18 2017-04-13 11:56:12
# 18      Test 2017-04-25 10:28:55 2017-04-25 10:30:30
# 19      Test 2017-04-25 10:28:55 2017-04-25 10:30:30

# %% [markdown]
# ## Keep only first start_date row when there are sevral consecutive start dates, same process for confirm dates (but last).
# #### this allows to keep track of start and confirm dates that are within the visit (and keep track of restarts)

# %%
# Sort by visit_id and date_time to ensure chronological order
df = df.sort_values(['visit_id', 'date_time'])

# Compare each start with the previous row in the same visit
df['prev_step'] = df.groupby('visit_id')['process_step'].shift(1)

# Keep rows:
# - all non-start steps, OR
# - first start in a consecutive sequence
df = df[
    (df['process_step'] != 'start') | 
    ((df['process_step'] == 'start') & (df['prev_step'] != 'start'))
]

# Drop helper column
df = df.drop(columns=['prev_step'])

# Reset index for clean DataFrame
df = df.reset_index(drop=True)

# %%
# Sort by visit_id and date_time
df = df.sort_values(['visit_id', 'date_time'])

# Compare each confirm with the next row in the same visit
df['next_step'] = df.groupby('visit_id')['process_step'].shift(-1)

# Keep rows:
# - all non-confirm steps, OR
# - last confirm in a consecutive sequence (next_step != confirm)
df = df[
    (df['process_step'] != 'confirm') |
    ((df['process_step'] == 'confirm') & (df['next_step'] != 'confirm'))
]

# Drop helper column
df = df.drop(columns=['next_step'])

# Reset index for a clean DataFrame
df = df.reset_index(drop=True)

# %%
# export the dataset
df_main = df.to_csv(config["output_data"]["file5"])
